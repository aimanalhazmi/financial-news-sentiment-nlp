# %% [markdown]
# # Financial News Sentiment Analysis
# Classify the sentiment of financial news headlines as positive, neutral, or negative using classical machine learning and neural network methods.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import re
import numpy as np
import random
import math
import string
from itertools import combinations
pd.set_option('display.max_colwidth',200)

# %% [markdown]
# ## Load Dataset:
# The dataset used is the **Financial Phrase Bank v1.0**, created by researchers at Aalto University. It contains 4846 financial and economic news sentences annotated for sentiment. This project specifically uses the **Sentences_50Agree.txt** file, which includes sentences where **at least 50% of annotators** agreed on the sentiment label.

# %%
def load_data(data_path: str, text_column: str, sentiment_col: str) -> pd.DataFrame:
    """Load data from a text file where each line contains text and label separated by '@'.
    Lines without the delimiter are skipped."""
    data = []
    skipped = 0
    print(f"Loading data from: {data_path} ...")
    with open(data_path, "r", encoding="latin1") as f:
        for line in f:
            line = line.strip()
            if "@" not in line:
                skipped += 1
                continue
            parts = line.split("@", 1)  # split only on first '@'
            data.append(parts)

    print(f"Loaded {len(data)} lines.")
    print(f"Skipped {skipped} lines without labels.")
    return pd.DataFrame(data, columns=[text_column, sentiment_col])

# %%
data_path = "../data/Sentences_50Agree.txt"
text_col = "news"
sentiment_col = "sentiment"
# %time
corpora = load_data(data_path=data_path, text_column=text_col, sentiment_col=sentiment_col)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.15 μs
# Loading data from: ../data/Sentences_50Agree.txt ...
# Loaded 4846 lines.
# Skipped 0 lines without labels.

# %% [markdown]
# corpora.head(10)

# %% [markdown]
# ## Textual Similarity

# %% [markdown]
# In this task, we measure the semantic similarity between 15 randomly selected positive financial sentences. We use
# the average of word vectors as a distributional semantics approach at the sentence level.

# %% [markdown]
# ### Preprocess
# Before computing sentence similarities, we apply some preprocessing steps to the entire dataset of 4846 sentences.
# These included: lowercasing the text, expanding contractions (e.g., “can’t” → “can not”, “I’m” → “I am”). This ensured cleaner, more consistent input for vector generation.

# %%
def contraction_expansion(text: str):
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"'re", " are", text)
    text = re.sub(r"'s", " is", text)
    text = re.sub(r"'d", " would", text)
    text = re.sub(r"'ll", " will", text)
    text = re.sub(r"'ve", " have", text)
    text = re.sub(r"'m", " am", text)
    return text


def clean_text(text: str) -> str:
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = contraction_expansion(text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
corpora[text_col] = corpora[text_col].apply(clean_text)
corpora.head(1)
# Out:
#                                                                                                                               news  \
# 0  according to gran , the company has no plans to move all production to russia , although that is where the company is growing .
#
#   sentiment
# 0   neutral

# %% [markdown]
# ### Select 15 random positive sentences

# %%
positive_corpora = corpora[corpora[sentiment_col] == "positive"]

# Randomly select 15 positive sentences
random.seed(42)
selected_positive_sentences = positive_corpora.sample(15, random_state=42)

selected_sentences = selected_positive_sentences[text_col].tolist()

# %%
selected_positive_sentences
# Out:
#                                                                                                                                                                                                          news  \
# 567                the new agreement , which expands a long-established cooperation between the companies , involves the transfer of certain engineering and documentation functions from larox to etteplan .
# 1752  ( adp news ) - finnish handling systems provider cargotec oyj ( hel : cgcbv ) announced on friday it won orders worth eur 10 million ( usd 13.2 m ) to deliver linkspans to jordan , morocco and ire...
# 995   the world is biggest magazine paper maker said the program to improve efficiency will include closing several of its least competitive mills and would cover all the company is operations resulting...
# 601                                                                          a january 11 , 2010 ephc board of directors has approved an increase in the quarterly dividend from $ 0.03 to $ 0.05 per share .
# 568                                              with this appointment kaupthing bank aims to further co-ordinate capital markets activities within the group and to improve the overall service to clients .
# 3129  st. petersburg , oct 14 ( prime-tass ) -- finnish tire producer nokian tyres plans to invest about 50 million euros in the expansion of its tire plant in the city of vsevolozhsk in russia is lenin...
# 760   during the past decade it has gradually divested noncore assets and bought several sports equipment makers , including california-based fitness products international and sparks , nevada-based ate...
# 463   - beijing xfn-asia - hong kong-listed standard chartered bank said it has signed a china mobile phone dealer financing agreement with nokia , making it the first foreign bank to offer financing to...
# 818                                                                                            according to schmardin , nordea will most likely try to win customers over from other pension fund providers .
# 1949                                                              this is a much better process than using virgin paper as it requires less transportation of wood pulp from places like finland and canada .
# 2605                                         the company said that it has started to investigate streamlining its operations in order to meet the tightening competition on the mobile phone charger market .
# 89                                                                                                               adjusted for changes in the group structure , the division is net sales increased by 1.7 % .
# 1691                                                                                            we can choose the most efficient , best overall value option for our customers already at the bidding stage .
# 1755  outotec oyj press release , february 19 , 2008 at 11.00 am outotec has won two large minerals processing technology orders from mirabela mineracao do brasil ltda , brazil and from cumerio med jsco...
# 201                                               finnish software developer done solutions oyj said its net profit increased to 3.5 mln euro ( $ 4.6 mln ) in 2006 from 2.3 mln euro ( $ 3.0 mln ) in 2005 .
#
#      sentiment
# 567   positive
# 1752  positive
# 995   positive
# 601   positive
# 568   positive
# 3129  positive
# 760   positive
# 463   positive
# 818   positive
# 1949  positive
# 2605  positive
# 89    positive
# 1691  positive
# 1755  positive
# 201   positive

# %% [markdown]
# ###  Load Word Vectors

# %% [markdown]
# For converting the words into vectors, we use two different methods:
# - **PMI (Pointwise Mutual Information):** We build custom word vectors using co-occurrence statistics from the
# entire dataset (4846 sentences). A sliding window (sizes 2–5) is used to count how often words appear near
# each other. The co-occurrence matrix is then transformed into a PMI matrix and each word is represented
# by its PMI vector.
# - **GloVe (Global Vectors for Word Representation):** We load pre-trained 50-dimensional word embeddings
# from glove.6B.50d.txt. These vectors were trained on a large external corpus and capture general semantic
# relationships between words.
#
# For both approaches, we compute the sentence vector by averaging the word vectors present in that sentence.
# Cosine similarity was is to measure how semantically close the sentence pairs are.

# %%
def load_word_vectors(method, tokenized_sentences=None, vocab=None, window_size=3):
    word_vectors = {}

    if method == "glove":
        with open("glove.6B.50d.txt", 'r', encoding='utf-8') as f:
            for line in f:
                parts = line.split()
                word = parts[0]
                vec = list(map(float, parts[1:]))
                word_vectors[word] = vec

    elif method == "pmi":
        if tokenized_sentences is None or vocab is None:
            print("PMI mode requires tokenized_sentences and vocab.")
            return {}

        word_to_idx = {word: i for i, word in enumerate(vocab)}
        co_occurrence = np.zeros((len(vocab), len(vocab)))

        for sent in tokenized_sentences:
            for i, center in enumerate(sent):
                center_idx = word_to_idx[center]
                for j in range(max(0, i - window_size), min(len(sent), i + window_size + 1)):
                    if i != j:
                        context = sent[j]
                        context_idx = word_to_idx[context]
                        co_occurrence[center_idx][context_idx] += 1

        total = np.sum(co_occurrence)
        word_probs = np.sum(co_occurrence, axis=1) / total
        pmi_matrix = np.zeros_like(co_occurrence)

        for i in range(len(vocab)):
            for j in range(len(vocab)):
                joint = co_occurrence[i][j] / total
                if joint > 0:
                    pmi_matrix[i][j] = max(0, np.log2(joint / (word_probs[i] * word_probs[j])))

        word_vectors = {word: pmi_matrix[word_to_idx[word]] for word in vocab}

    else:
        print("Invalid method.")
    
    return word_vectors

# %% [markdown]
# ### Convert Sentences to Vectors

# %%
def vectorize_sentences(sentences, method, word_vectors):
    sentence_vectors = []

    if method == "glove":
        vector_size = 50
    elif method == "pmi":
        vector_size = len(next(iter(word_vectors.values())))
    else:
        print("Invalid method.")
        return []

    for sentence in sentences:
        words = sentence.split()
        vectors = [word_vectors[word] for word in words if word in word_vectors]

        if vectors:
            avg_vector = [sum(x)/len(x) for x in zip(*vectors)]
        else:
            avg_vector = [0.0] * vector_size

        sentence_vectors.append(avg_vector)

    return sentence_vectors

# %% [markdown]
# ### Compute Similarity and print results

# %%
def cosine_sim(vec1, vec2):
    dot = sum(a * b for a, b in zip(vec1, vec2))
    norm1 = math.sqrt(sum(a * a for a in vec1))
    norm2 = math.sqrt(sum(b * b for b in vec2))
    return dot / (norm1 * norm2) if norm1 and norm2 else 0

# %%
def compute_and_display_similarities(sentences, sentence_vectors, label, display=False):
    similarities = []
    for i in range(len(sentence_vectors)):
        for j in range(i + 1, len(sentence_vectors)):
            sim = cosine_sim(sentence_vectors[i], sentence_vectors[j])
            similarities.append(sim)

    avg_sim = sum(similarities) / len(similarities)
    print(f"\n Average Cosine Similarity using {label}: {avg_sim:.4f}\n")

    if display:
        print(f"\nPairwise Cosine Similarities ({label}):\n")
        for (i, s1), (j, s2) in combinations(enumerate(sentences), 2):
            sim = cosine_sim(sentence_vectors[i], sentence_vectors[j])
            print(f"[{i+1}] \"{s1[:60]}...\"")
            print(f"[{j+1}] \"{s2[:60]}...\"")
            print(f"   → Cosine Similarity: {sim:.4f}\n")
    
    return avg_sim

# %% [markdown]
# ### Run

# %%
# GloVe
glove_vectors = load_word_vectors("glove")
glove_sentence_vectors = vectorize_sentences(selected_sentences, "glove", glove_vectors)
glove_avg_sim = compute_and_display_similarities(selected_sentences, glove_sentence_vectors, "GloVe", display = True)
# Out:
#  Average Cosine Similarity using GloVe: 0.9108
#
#
# Pairwise Cosine Similarities (GloVe):
#
# [1] "the new agreement , which expands a long-established coopera..."
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
#    → Cosine Similarity: 0.8701
#
# [1] "the new agreement , which expands a long-established coopera..."
# [3] "the world is biggest magazine paper maker said the program t..."
#    → Cosine Similarity: 0.9505
#
# [1] "the new agreement , which expands a long-established coopera..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.8865
#
# [1] "the new agreement , which expands a long-established coopera..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.9650
#
# [1] "the new agreement , which expands a long-established coopera..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.9201
#
# [1] "the new agreement , which expands a long-established coopera..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.9284
#
# [1] "the new agreement , which expands a long-established coopera..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9479
#
# [1] "the new agreement , which expands a long-established coopera..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9218
#
# [1] "the new agreement , which expands a long-established coopera..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9515
#
# [1] "the new agreement , which expands a long-established coopera..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9600
#
# [1] "the new agreement , which expands a long-established coopera..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9334
#
# [1] "the new agreement , which expands a long-established coopera..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9311
#
# [1] "the new agreement , which expands a long-established coopera..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.8941
#
# [1] "the new agreement , which expands a long-established coopera..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.7883
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [3] "the world is biggest magazine paper maker said the program t..."
#    → Cosine Similarity: 0.9185
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.9245
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.8649
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.9386
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.8444
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9118
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.8861
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.8711
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.8755
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9096
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.8448
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9488
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.9391
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.9363
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.9439
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.9471
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.9415
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9586
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9530
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9563
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9571
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9598
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9480
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9189
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8889
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.8827
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.9087
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.8600
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9101
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.8997
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.8771
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.8922
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9527
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.8701
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9035
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.9247
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.9125
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.8979
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9568
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9528
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9147
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9663
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9268
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9329
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.8951
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8009
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.8999
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9391
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9092
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9225
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9344
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9259
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.8857
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9538
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8528
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.9255
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9053
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9343
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9370
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9140
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9133
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.8997
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.7803
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.9512
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9327
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9699
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9232
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9305
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9268
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8454
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.9244
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9501
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9103
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9593
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9097
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8320
#
# [10] "this is a much better process than using virgin paper as it ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.9377
#
# [10] "this is a much better process than using virgin paper as it ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9347
#
# [10] "this is a much better process than using virgin paper as it ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9530
#
# [10] "this is a much better process than using virgin paper as it ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9080
#
# [10] "this is a much better process than using virgin paper as it ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.7989
#
# [11] "the company said that it has started to investigate streamli..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.9282
#
# [11] "the company said that it has started to investigate streamli..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9461
#
# [11] "the company said that it has started to investigate streamli..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9144
#
# [11] "the company said that it has started to investigate streamli..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8047
#
# [12] "adjusted for changes in the group structure , the division i..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.9095
#
# [12] "adjusted for changes in the group structure , the division i..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.9104
#
# [12] "adjusted for changes in the group structure , the division i..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8919
#
# [13] "we can choose the most efficient , best overall value option..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.8802
#
# [13] "we can choose the most efficient , best overall value option..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.7813
#
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.8649

# %%
tokenized_all = [s.lower().split() for s in corpora[text_col].tolist()]
vocab = sorted(set(word for sent in tokenized_all for word in sent))
pmi_similarities = []
for window in [2, 3, 4, 5]:
    print(f"Window Size = {window}")
    pmi_vectors = load_word_vectors("pmi", tokenized_sentences=tokenized_all, vocab=vocab, window_size=window)
    pmi_sentence_vectors = vectorize_sentences(selected_sentences, "pmi", pmi_vectors)
    if window==5:
        display = True
    else: 
        display = False
    pmi_avg_sim = compute_and_display_similarities(selected_sentences, pmi_sentence_vectors, "PMI", display=display)
    pmi_similarities.append(pmi_avg_sim)
# Out:
# Window Size = 2
#
#  Average Cosine Similarity using PMI: 0.6008
#
# Window Size = 3
#
#  Average Cosine Similarity using PMI: 0.6098
#
# Window Size = 4
#
#  Average Cosine Similarity using PMI: 0.6163
#
# Window Size = 5
#
#  Average Cosine Similarity using PMI: 0.6199
#
#
# Pairwise Cosine Similarities (PMI):
#
# [1] "the new agreement , which expands a long-established coopera..."
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
#    → Cosine Similarity: 0.5050
#
# [1] "the new agreement , which expands a long-established coopera..."
# [3] "the world is biggest magazine paper maker said the program t..."
#    → Cosine Similarity: 0.7595
#
# [1] "the new agreement , which expands a long-established coopera..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.7415
#
# [1] "the new agreement , which expands a long-established coopera..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.7383
#
# [1] "the new agreement , which expands a long-established coopera..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.7490
#
# [1] "the new agreement , which expands a long-established coopera..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.7616
#
# [1] "the new agreement , which expands a long-established coopera..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.7176
#
# [1] "the new agreement , which expands a long-established coopera..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.6957
#
# [1] "the new agreement , which expands a long-established coopera..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6964
#
# [1] "the new agreement , which expands a long-established coopera..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.7217
#
# [1] "the new agreement , which expands a long-established coopera..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.7257
#
# [1] "the new agreement , which expands a long-established coopera..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6963
#
# [1] "the new agreement , which expands a long-established coopera..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.6932
#
# [1] "the new agreement , which expands a long-established coopera..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4226
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [3] "the world is biggest magazine paper maker said the program t..."
#    → Cosine Similarity: 0.5381
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.5510
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.5133
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.6194
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.5007
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.5748
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.5084
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.4777
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.5426
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.4977
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.4097
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5377
#
# [2] "( adp news ) - finnish handling systems provider cargotec oy..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.7252
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
#    → Cosine Similarity: 0.7033
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.7274
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.8229
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.6788
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.7010
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.6535
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.7057
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.7940
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.7466
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6728
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5514
#
# [3] "the world is biggest magazine paper maker said the program t..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4789
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
#    → Cosine Similarity: 0.6481
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.7305
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.6250
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.6415
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.6493
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6493
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.6912
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6798
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6001
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.6360
#
# [4] "a january 11 , 2010 ephc board of directors has approved an ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.6280
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
#    → Cosine Similarity: 0.6623
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.6079
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.7291
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.7162
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6145
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.7465
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6541
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6259
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5097
#
# [5] "with this appointment kaupthing bank aims to further co-ordi..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4152
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [7] "during the past decade it has gradually divested noncore ass..."
#    → Cosine Similarity: 0.6521
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.6704
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.6129
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6426
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.7466
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.7701
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6365
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.6068
#
# [6] "st. petersburg , oct 14 ( prime-tass ) -- finnish tire produ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.5658
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
#    → Cosine Similarity: 0.6744
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.5714
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6810
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.6115
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6262
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6008
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.7128
#
# [7] "during the past decade it has gradually divested noncore ass..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.3572
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [9] "according to schmardin , nordea will most likely try to win ..."
#    → Cosine Similarity: 0.6162
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.6441
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.7676
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6174
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.5880
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5686
#
# [8] "- beijing xfn-asia - hong kong-listed standard chartered ban..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4299
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [10] "this is a much better process than using virgin paper as it ..."
#    → Cosine Similarity: 0.5896
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.6559
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.5961
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6234
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.6077
#
# [9] "according to schmardin , nordea will most likely try to win ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4437
#
# [10] "this is a much better process than using virgin paper as it ..."
# [11] "the company said that it has started to investigate streamli..."
#    → Cosine Similarity: 0.6141
#
# [10] "this is a much better process than using virgin paper as it ..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6259
#
# [10] "this is a much better process than using virgin paper as it ..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.5793
#
# [10] "this is a much better process than using virgin paper as it ..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5892
#
# [10] "this is a much better process than using virgin paper as it ..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4149
#
# [11] "the company said that it has started to investigate streamli..."
# [12] "adjusted for changes in the group structure , the division i..."
#    → Cosine Similarity: 0.6862
#
# [11] "the company said that it has started to investigate streamli..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6520
#
# [11] "the company said that it has started to investigate streamli..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5348
#
# [11] "the company said that it has started to investigate streamli..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4721
#
# [12] "adjusted for changes in the group structure , the division i..."
# [13] "we can choose the most efficient , best overall value option..."
#    → Cosine Similarity: 0.6687
#
# [12] "adjusted for changes in the group structure , the division i..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5858
#
# [12] "adjusted for changes in the group structure , the division i..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.5034
#
# [13] "we can choose the most efficient , best overall value option..."
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
#    → Cosine Similarity: 0.5848
#
# [13] "we can choose the most efficient , best overall value option..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.3421
#
# [14] "outotec oyj press release , february 19 , 2008 at 11.00 am o..."
# [15] "finnish software developer done solutions oyj said its net p..."
#    → Cosine Similarity: 0.4307

# %% [markdown]
# ### Summary
# GloVe consistently provides higher similarity scores than PMI, likely due to being trained on large external corpora.
# However, PMI still captures meaningful relationships, especially with larger window sizes (e.g., window = 5).

# %%
print("\nSummary:")
print(f"GloVe based average similarity: {glove_avg_sim:.4f}")
for i, pmi_avg_sim in enumerate(pmi_similarities):
    print(f"PMI based average similarity with window {i+2}:   {pmi_avg_sim:.4f}")
# Out:
# Summary:
# GloVe based average similarity: 0.9108
# PMI based average similarity with window 2:   0.6008
# PMI based average similarity with window 3:   0.6098
# PMI based average similarity with window 4:   0.6163
# PMI based average similarity with window 5:   0.6199

# %%
positive_corpora[text_col][567]
# Out:
# 'the new agreement , which expands a long-established cooperation between the companies , involves the transfer of certain engineering and documentation functions from larox to etteplan .'

# %%
positive_corpora[text_col][1752]
# Out:
# '( adp news ) - finnish handling systems provider cargotec oyj ( hel : cgcbv ) announced on friday it won orders worth eur 10 million ( usd 13.2 m ) to deliver linkspans to jordan , morocco and ireland .'

# %%
positive_corpora[text_col][995]
# Out:
# 'the world is biggest magazine paper maker said the program to improve efficiency will include closing several of its least competitive mills and would cover all the company is operations resulting in annual savings of some euro200 million us$ 240 million .'
